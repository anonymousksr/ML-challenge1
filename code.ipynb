# %%
#importing the essential python libraries
import pandas as pd
import numpy as np

# %%
#loading the dataset 
df = pd.read_csv(r"kaggledata.csv")
df
# Out:
#     Roll CT-1 (Marks: 20)  ... Exam Mark (105).1 Mark total 300
# 0    2.0             12.5  ...              46.5          167.0
# 1    3.0                9  ...              44.0          138.5
# 2    4.0               10  ...              43.0          136.0
# 3    5.0               14  ...              44.0          166.0
# 4    6.0             14.5  ...              74.5          176.5
# ..   ...              ...  ...               ...            ...
# 58  60.0               12  ...              66.0          197.5
# 59  61.0             19.5  ...              84.0          200.0
# 60  62.0                0  ...              77.5          184.5
# 61  63.0                0  ...              39.0          108.5
# 62  64.0               18  ...              45.0          133.5
#
# [63 rows x 12 columns]

# %%
#Getting to know the different columns in the dataset
header = list(df.columns.values)
header
# Out:
# ['Roll',
#  'CT-1 (Marks: 20)',
#  'CT-2 (Marks: 20)',
#  'CT-3 (Marks: 20)',
#  'CT-4 (Marks: 20)',
#  'Class Test (Total of best 3, Marks: 60)',
#  'Attendance (Marks: 15)',
#  'Observation (Marks: 15)',
#  'Total (Marks: 90)',
#  'Exam Mark (105)',
#  'Exam Mark (105).1',
#  'Mark total 300']

# %%
#Viewing the rows with null values 
df.iloc[10:25,:]
# Out:
#     Roll  CT-1 (Marks: 20)  ... Exam Mark (105).1 Mark total 300
# 10  12.0               7.5  ...              45.0          163.0
# 11  13.0              12.5  ...              59.5          181.0
# 12  14.0               7.5  ...              23.5          131.0
# 13  15.0               7.5  ...              64.0          180.5
# 14  16.0                 1  ...               2.0           52.0
# 15   NaN               NaN  ...               NaN            NaN
# 16   NaN               NaN  ...               NaN            NaN
# 17  19.0  CT-1 (Marks: 20)  ...               NaN            NaN
# 18  20.0               9.5  ...              25.5          117.0
# 19  21.0              14.5  ...              47.0          144.0
# 20  22.0                 7  ...              55.5          174.5
# 21  23.0                 5  ...              79.5          202.0
# 22  24.0                 0  ...              67.0          178.5
# ...

# %%
#Replacing the null values
df.replace('', np.nan, inplace=True)
df
# Out:
#     Roll CT-1 (Marks: 20)  ... Exam Mark (105).1 Mark total 300
# 0    2.0             12.5  ...              46.5          167.0
# 1    3.0                9  ...              44.0          138.5
# 2    4.0               10  ...              43.0          136.0
# 3    5.0               14  ...              44.0          166.0
# 4    6.0             14.5  ...              74.5          176.5
# ..   ...              ...  ...               ...            ...
# 58  60.0               12  ...              66.0          197.5
# 59  61.0             19.5  ...              84.0          200.0
# 60  62.0                0  ...              77.5          184.5
# 61  63.0                0  ...              39.0          108.5
# 62  64.0               18  ...              45.0          133.5
#
# [63 rows x 12 columns]

# %%
#Dropping the rows with null values
df.dropna(inplace=True)
df
# Out:
#     Roll CT-1 (Marks: 20)  ... Exam Mark (105).1 Mark total 300
# 0    2.0             12.5  ...              46.5          167.0
# 1    3.0                9  ...              44.0          138.5
# 2    4.0               10  ...              43.0          136.0
# 3    5.0               14  ...              44.0          166.0
# 4    6.0             14.5  ...              74.5          176.5
# 5    7.0             13.5  ...              70.0          225.0
# 6    8.0               14  ...              79.5          225.0
# 7    9.0               11  ...              67.0          195.5
# 8   10.0                8  ...              38.5          131.5
# 9   11.0             11.5  ...              41.0          150.0
# 10  12.0              7.5  ...              45.0          163.0
# 11  13.0             12.5  ...              59.5          181.0
# 12  14.0              7.5  ...              23.5          131.0
# 13  15.0              7.5  ...              64.0          180.5
# ...

# %%
#Importing the matplotlib library to plot a graph 
import matplotlib.pyplot as plt

# %%
#plotting a scatter graph i.e, Attendance versus Total marks of student
plt.scatter( df["Attendance (Marks: 15)"].values , df["Mark total 300"].values , s=5, c='red')
#Naming the X-axis and Y-axis
plt.xlabel('attendance')
plt.ylabel('marks')
#Syntax to view the graph
plt.show()

# %%
#Viewing the datatypes of all columns of the dataframe
df.dtypes
# Out:
# Roll                                       float64
# CT-1 (Marks: 20)                            object
# CT-2 (Marks: 20)                            object
# CT-3 (Marks: 20)                            object
# CT-4 (Marks: 20)                            object
# Class Test (Total of best 3, Marks: 60)     object
# Attendance (Marks: 15)                      object
# Observation (Marks: 15)                     object
# Total (Marks: 90)                           object
# Exam Mark (105)                            float64
# Exam Mark (105).1                          float64
# Mark total 300                             float64
# dtype: object

# %%
#To convert all the columns of dataframe to float datatype
df = df.astype(float)

# %%
#To find the correlation factor betwwen Attendance and Total Marks
df["Attendance (Marks: 15)"].corr(df["Mark total 300"])
# Out:
# 0.16831203521391597

# %%
#Since the correlation factor is near to zero we can say that there is no relationship between Attendance and the total marks of the student
